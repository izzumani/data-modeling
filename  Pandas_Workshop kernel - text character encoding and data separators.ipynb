# %%
import pandas as pd

# %%
data = pd.read_csv('./Datasets/thyroid.tsv',encoding = 'utf_16_le',sep = '\t')
data.head()
# Out:
#   age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41   F            f                  f                         f    f
# 1  23   F            f                  f                         f    f
# 2  46   M            f                  f                         f    f
# 3  70   F            t                  f                         f    f
# 4  70   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  ...  TT4  \
# 0        f               f              f                 f  ...  125
# 1        f               f              f                 f  ...  102
# 2        f               f              f                 f  ...  109
# 3        f               f              f                 f  ...  175
# 4        f               f              f                 f  ...   61
#
#   T4U_measured   T4U FTI_measured  FTI TBG_measured TBG referral_source  \
# ...
